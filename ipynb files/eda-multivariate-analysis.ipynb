# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default')
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1.1)

custom_palette = sns.color_palette("husl", 8)  
sns.set_palette(custom_palette)

# %%
df = pd.read_csv('../data/gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                     society      sector  price  \
# 0          flat        shree vardhman flora   sector 90   0.85
# 1          flat           gls arawali homes  sohna road   0.27
# 2         house               bptp pedestal  sector 70a   0.90
# 3          flat  central park flower valley   sector 33   2.30
# 4          flat          sare crescent parc   sector 92   0.51
#
#    price_per_sqft    area                                       areaWithType  \
# 0          4404.0  1930.0  Super Built up area 1930(179.3 sq.m.)Carpet ar...
# 1          4600.0   587.0               Super Built up area 576(53.51 sq.m.)
# 2          7582.0  1187.0                   Carpet area: 1187 (110.28 sq.m.)
# 3         12777.0  1800.0                   Carpet area: 1800 (167.23 sq.m.)
# 4          4080.0  1250.0             Super Built up area 1250(116.13 sq.m.)
#
#    bedRoom  bathroom balcony  ...  super_built_up_area built_up_area  \
# 0        3         4       3  ...               1930.0           NaN
# 1        2         2       2  ...                576.0           NaN
# 2        2         2      3+  ...                  NaN           NaN
# 3        4         4      3+  ...                  NaN           NaN
# 4        3         2       2  ...               1250.0           NaN
#
#   carpet_area  study room  servant room  store room  pooja room  others  \
# 0      1450.0           0             1           1           0       0
# 1         NaN           0             0           0           0       0
# 2      1187.0           0             1           0           0       1
# 3      1800.0           0             1           0           1       0
# 4         NaN           0             0           0           0       0
#
#    furnishing_type  luxury_score
# 0                1           110
# 1                1            42
# 2                1           153
# 3                1            42
# 4                1            72
#
# [5 rows x 23 columns]

# %% [markdown]
# ### property_type vs price

# %%
# Now your plots will automatically use different colors for different categories
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='property_type', y='price', estimator=np.median, 
            hue='property_type', legend=False, palette='Set2')
plt.title('Median Price by Property Type')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='property_type', y='price', palette='Set2')
plt.title('Price Distribution by Property Type')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\ajjur\AppData\Local\Temp\ipykernel_53848\3250906125.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='property_type', y='price', palette='Set2')

# %% [markdown]
# ### property_type vs area

# %%
sns.barplot(x=df['property_type'], y=df['built_up_area'], estimator=np.median, palette='Set2')
# Out:
# C:\Users\ajjur\AppData\Local\Temp\ipykernel_53848\902812954.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['property_type'], y=df['built_up_area'], estimator=np.median, palette='Set2')
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
# removing that crazy outlier
df = df[df['built_up_area'] != 737147]

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'], palette='Set2')
# Out:
# C:\Users\ajjur\AppData\Local\Temp\ipykernel_53848\20087839.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['property_type'], y=df['built_up_area'], palette='Set2')
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# ### property_type vs price_per_sqft

# %%
sns.barplot(x=df['property_type'], y=df['price_per_sqft'], estimator=np.median, palette='Set2')
# Out:
# C:\Users\ajjur\AppData\Local\Temp\ipykernel_53848\3044775771.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['property_type'], y=df['price_per_sqft'], estimator=np.median, palette='Set2')
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'], y=df['price_per_sqft'], palette='Set2')
# Out:
# C:\Users\ajjur\AppData\Local\Temp\ipykernel_53848\4073904633.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['property_type'], y=df['price_per_sqft'], palette='Set2')
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
# check outliers
df[df['price_per_sqft'] > 100000][['property_type','society','sector','price','price_per_sqft','area','areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#      property_type                      society     sector  price  \
# 27           house       emaar the palm springs  sector 54  24.00
# 32           house       unitech deerwood chase  sector 50   8.45
# 97           house                   ardee city  sector 52   5.50
# 277          house         eros rosewood villas  sector 49   2.75
# 356          house                    rk excelo  sector 12   0.60
# 425          house                  independent  sector 54   3.75
# 444          house     unitech uniworld resorts  sector 33   9.50
# 727           flat           ambience caitriona  sector 24  14.00
# 749          house  unitech nirvana birch court  sector 50   7.10
# 815          house         bhim nagar, sector 6   sector 6   0.85
# 1071         house                  independent   sector 4   0.60
# 1635         house                  independent  sector 12   6.00
# 1732         house                  independent  sector 23   2.80
# 1788         house                  independent  sector 17   3.50
# 1963         house               uppal southend  sector 49   6.75
# 2001         house                  independent  sector 12   3.50
# 2119         house                  independent  sector 24  10.00
# 2155         house       dlf city plots phase 2  sector 25  10.50
# 2198         house                        ansal  sector 43   1.85
# 2367         house          huda plot sector 38  sector 38   4.30
# 2593         house                  independent  sector 38   8.00
# 2609         house           vipul tatvam villa  sector 48   7.25
# 2949         house       dlf city plots phase 2  sector 25  10.00
# 3116         house                  independent  sector 55   1.45
# 3154         house     unitech uniworld resorts  sector 33  10.00
# 3302         house                  independent  sector 57   8.00
# 3638         house            vatika india next  sector 82   7.00
# 3678         house                dlf the grove  sector 54   5.70
# 3709         house                  independent  sector 28   4.50
#
#       price_per_sqft   area  \
# 27          600000.0  400.0
# 32          235376.0  359.0
# 97          183333.0  300.0
# 277         178571.0  154.0
# 356         120000.0   50.0
# 425         234375.0  160.0
# 444         173992.0  546.0
# 727         200000.0  700.0
# 749         283333.0  251.0
# 815         126865.0   67.0
# 1071        105263.0   57.0
# 1635        315789.0  190.0
# 1732        161849.0  173.0
# 1788        218750.0  160.0
# 1963        290948.0  232.0
# 2001        133079.0  263.0
# 2119        229885.0  435.0
# 2155        261194.0  402.0
# 2198        308333.0   60.0
# 2367        245398.0  175.0
# 2593        230547.0  347.0
# 2609        201388.0  360.0
# 2949        400000.0  250.0
# 3116        241666.0   60.0
# 3154        181818.0  550.0
# 3302        266666.0  300.0
# 3638        194444.0  360.0
# 3678        211111.0  270.0
# 3709        125000.0  360.0
#
#                                            areaWithType  super_built_up_area  \
# 27                           Plot area 400(37.16 sq.m.)                  NaN
# 32                           Plot area 359(33.35 sq.m.)                  NaN
# 97                           Plot area 300(27.87 sq.m.)                  NaN
# 277   Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...                  NaN
# 356   Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...                  NaN
# 425                          Plot area 160(14.86 sq.m.)                  NaN
# 444                          Plot area 546(50.73 sq.m.)                  NaN
# 727                    Built Up area: 700 (65.03 sq.m.)                  NaN
# 749                           Plot area 240(22.3 sq.m.)                  NaN
# 815                            Plot area 67(6.22 sq.m.)                  NaN
# 1071                            Plot area 57(5.3 sq.m.)                  NaN
# 1635  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...                  NaN
# 1732  Plot area 173(16.07 sq.m.)Built Up area: 160 s...                  NaN
# 1788                   Built Up area: 160 (14.86 sq.m.)                  NaN
# 1963                         Plot area 232(21.55 sq.m.)                  NaN
# 2001  Plot area 263(24.43 sq.m.)Built Up area: 4800 ...                  NaN
# 2119                     Carpet area: 435 (40.41 sq.m.)                  NaN
# 2155                         Plot area 402(37.35 sq.m.)                  NaN
# 2198                           Plot area 60(5.57 sq.m.)                  NaN
# 2367  Plot area 163(15.14 sq.m.)Built Up area: 145 s...                  NaN
# 2593  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...                  NaN
# 2609                         Plot area 360(33.45 sq.m.)                  NaN
# 2949                         Plot area 250(23.23 sq.m.)                  NaN
# 3116                           Plot area 60(5.57 sq.m.)                  NaN
# 3154                          Plot area 550(51.1 sq.m.)                  NaN
# 3302                         Plot area 300(27.87 sq.m.)                  NaN
# 3638  Plot area 360(33.45 sq.m.)Built Up area: 3900 ...                  NaN
# 3678                   Built Up area: 270 (25.08 sq.m.)                  NaN
# 3709                   Built Up area: 360 (33.45 sq.m.)                  NaN
#
#       built_up_area  carpet_area
# 27            400.0          NaN
# 32            359.0          NaN
# 97            300.0          NaN
# 277             NaN       1650.0
# 356            30.0         15.0
# 425           160.0          NaN
# 444           546.0          NaN
# 727           700.0          NaN
# 749           240.0          NaN
# 815            67.0          NaN
# 1071           57.0          NaN
# 1635            NaN       1600.0
# 1732          160.0        150.0
# 1788          160.0          NaN
# 1963          232.0          NaN
# 2001         4800.0       4400.0
# 2119            NaN        435.0
# 2155          402.0          NaN
# 2198           60.0          NaN
# 2367          145.0          NaN
# 2593          347.0        215.0
# 2609          360.0          NaN
# 2949          250.0          NaN
# 3116           60.0          NaN
# 3154          550.0          NaN
# 3302          300.0          NaN
# 3638         3900.0       3743.0
# 3678          270.0          NaN
# 3709          360.0          NaN

# %%
df.head()
# Out:
#   property_type                     society      sector  price  \
# 0          flat        shree vardhman flora   sector 90   0.85
# 1          flat           gls arawali homes  sohna road   0.27
# 2         house               bptp pedestal  sector 70a   0.90
# 3          flat  central park flower valley   sector 33   2.30
# 4          flat          sare crescent parc   sector 92   0.51
#
#    price_per_sqft    area                                       areaWithType  \
# 0          4404.0  1930.0  Super Built up area 1930(179.3 sq.m.)Carpet ar...
# 1          4600.0   587.0               Super Built up area 576(53.51 sq.m.)
# 2          7582.0  1187.0                   Carpet area: 1187 (110.28 sq.m.)
# 3         12777.0  1800.0                   Carpet area: 1800 (167.23 sq.m.)
# 4          4080.0  1250.0             Super Built up area 1250(116.13 sq.m.)
#
#    bedRoom  bathroom balcony  ...  super_built_up_area built_up_area  \
# 0        3         4       3  ...               1930.0           NaN
# 1        2         2       2  ...                576.0           NaN
# 2        2         2      3+  ...                  NaN           NaN
# 3        4         4      3+  ...                  NaN           NaN
# 4        3         2       2  ...               1250.0           NaN
#
#   carpet_area  study room  servant room  store room  pooja room  others  \
# 0      1450.0           0             1           1           0       0
# 1         NaN           0             0           0           0       0
# 2      1187.0           0             1           0           0       1
# 3      1800.0           0             1           0           1       0
# 4         NaN           0             0           0           0       0
#
#    furnishing_type  luxury_score
# 0                1           110
# 1                1            42
# 2                1           153
# 3                1            42
# 4                1            72
#
# [5 rows x 23 columns]

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
# checking outliers
df[df['bedRoom'] >= 10]
# Out:
#      property_type                     society     sector  price  \
# 41           house                 independent  sector 25    NaN
# 96           house                 independent  sector 55   9.19
# 175          house                 independent  sector 41   4.25
# 305          house                 independent  sector 26  10.50
# 317          house                 independent  sector 26   8.49
# ...            ...                         ...        ...    ...
# 3452         house   ganpati heights apartment  sector 13   1.25
# 3480         house  unitech palms south city 1  sector 41   9.35
# 3496         house                 independent  sector 43   7.50
# 3520         house                 independent  sector 11   3.50
# 3555         house                 independent  sector 24   4.50
#
#       price_per_sqft     area  \
# 41               NaN      NaN
# 96           34037.0   2700.0
# 175          26235.0   1620.0
# 305          43210.0   2430.0
# 317          47167.0   1800.0
# ...              ...      ...
# 3452           151.0  82781.0
# 3480         28858.0   3240.0
# 3496         38760.0   1935.0
# 3520         15555.0   2250.0
# 3555         33333.0   1350.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 41    Plot area 250(209.03 sq.m.)Built Up area: 260 ...       12        12
# 96                          Plot area 300(250.84 sq.m.)       16        18
# 175                          Plot area 180(150.5 sq.m.)       10         9
# 305   Plot area 302(252.51 sq.m.)Built Up area: 300 ...       12        12
# 317                         Plot area 200(167.23 sq.m.)       12        12
# ...                                                 ...      ...       ...
# 3452                       Plot area 115(7692.86 sq.m.)       10         6
# 3480  Plot area 3240(301.01 sq.m.)Built Up area: 750...       10        10
# 3496                        Plot area 215(179.77 sq.m.)       12        12
# 3520                 Built Up area: 2250 (209.03 sq.m.)       10         1
# 3555  Plot area 163(136.29 sq.m.)Built Up area: 160 ...       10         8
#
#      balcony  ...  super_built_up_area built_up_area carpet_area  study room  \
# 41        3+  ...                  NaN         260.0       245.0           1
# 96         2  ...                  NaN        2700.0         NaN           0
# 175       3+  ...                  NaN        1620.0         NaN           1
# 305       3+  ...                  NaN         300.0       270.0           0
# 317       3+  ...                  NaN        1800.0         NaN           0
# ...      ...  ...                  ...           ...         ...         ...
# 3452       2  ...                  NaN         115.0         NaN           0
# 3480      3+  ...                  NaN        7500.0      6000.0           1
# 3496      3+  ...                  NaN        1935.0         NaN           1
# 3520       0  ...                  NaN        2250.0         NaN           0
# 3555      3+  ...                  NaN         160.0       150.0           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# 41               1           0           1       1                2
# 96               1           0           1       0                0
# 175              1           0           0       0                0
# 305              1           0           1       0                0
# 317              1           0           1       0                0
# ...            ...         ...         ...     ...              ...
# 3452             0           0           0       1                1
# 3480             1           0           0       0                0
# 3496             1           1           1       0                0
# 3520             0           0           0       0                1
# 3555             1           1           0       0                0
#
#       luxury_score
# 41             144
# 96              49
# 175             36
# 305             72
# 317             42
# ...            ...
# 3452             7
# 3480            70
# 3496            72
# 3520             0
# 3555            56
#
# [72 rows x 23 columns]

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
# checking for outliers
df[(df['property_type'] == 'house') & (df['floorNum'] > 10)]
# Out:
#      property_type                  society      sector  price  \
# 186          house              spaze privy   sector 72   3.09
# 312          house      satya the hermitage  sector 103   3.15
# 355          house              greenopolis   sector 89   0.70
# 567          house           ats tourmaline  sector 109   1.87
# 735          house      ireo victory valley   sector 67   8.00
# 1042         house         suncity township   sector 54   2.00
# 1300         house  indiabulls centrum park  sector 103   3.25
# 1718         house              independent   sector 92   1.80
# 2715         house              spaze privy   sector 72   3.10
# 2859         house          godrej meridien  sector 106   5.60
# 2891         house        suncity avenue 76   sector 76   0.75
# 3230         house   vatika the seven lamps   sector 82   1.60
# 3447         house           dlf the arbour   sector 63   8.50
# 3621         house               ninex city   sector 76   1.75
#
#       price_per_sqft    area  \
# 186           6981.0  4426.0
# 312           6702.0  4700.0
# 355           5397.0  1297.0
# 567           8697.0  2150.0
# 735          22222.0  3600.0
# 1042         30968.0   646.0
# 1300          8125.0  4000.0
# 1718          7627.0  2360.0
# 2715          8486.0  3653.0
# 2859         14000.0  4000.0
# 2891         10067.0   745.0
# 3230          6597.0  2425.0
# 3447         21519.0  3950.0
# 3621          6250.0  2800.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 186   Built Up area: 3653 (339.37 sq.m.)Carpet area:...        5         5
# 312                  Built Up area: 4700 (436.64 sq.m.)        4         5
# 355                   Built Up area: 1297 (120.5 sq.m.)        2         2
# 567                  Built Up area: 2150 (199.74 sq.m.)        3         4
# 735                         Plot area 400(334.45 sq.m.)        6         7
# 1042  Plot area 60Built Up area: 60 sq.m.Carpet area...        9         9
# 1300                       Plot area 4000(371.61 sq.m.)        4         3
# 1718                 Built Up area: 2360 (219.25 sq.m.)        4         5
# 2715                       Plot area 3653(339.37 sq.m.)        5         5
# 2859                       Plot area 4000(371.61 sq.m.)        5         4
# 2891  Plot area 745(69.21 sq.m.)Built Up area: 745 s...        2         2
# 3230                       Plot area 2425(225.29 sq.m.)        4         4
# 3447                 Built Up area: 3950 (366.97 sq.m.)        4         4
# 3621                   Carpet area: 2800 (260.13 sq.m.)        4         4
#
#      balcony  ...  super_built_up_area built_up_area carpet_area  study room  \
# 186       3+  ...                  NaN        3653.0      2922.0           0
# 312        0  ...                  NaN        4700.0         NaN           0
# 355        2  ...                  NaN        1297.0         NaN           0
# 567        0  ...                  NaN        2150.0         NaN           0
# 735       3+  ...                  NaN        3600.0         NaN           1
# 1042       3  ...                  NaN          60.0        59.0           0
# 1300      3+  ...                  NaN        4000.0         NaN           0
# 1718       0  ...                  NaN        2360.0         NaN           0
# 2715      3+  ...                  NaN        3653.0         NaN           0
# 2859      3+  ...                  NaN        4000.0         NaN           1
# 2891       2  ...                  NaN         745.0         NaN           0
# 3230      3+  ...                  NaN        2425.0         NaN           0
# 3447      3+  ...                  NaN        3950.0         NaN           0
# 3621       0  ...                  NaN           NaN      2800.0           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# 186              1           0           0       0                0
# 312              0           0           0       0                1
# 355              0           0           0       0                1
# 567              0           0           0       0                1
# 735              1           0           1       0                0
# 1042             1           0           0       0                2
# 1300             0           0           0       0                1
# 1718             0           0           0       0                1
# 2715             0           0           0       0                1
# 2859             1           1           1       0                1
# 2891             0           0           0       0                1
# 3230             1           0           0       0                1
# 3447             0           0           0       0                1
# 3621             0           0           0       0                1
#
#       luxury_score
# 186             33
# 312             61
# 355              0
# 567              0
# 735             49
# 1042             7
# 1300            51
# 1718             0
# 2715             0
# 2859           151
# 2891            40
# 3230            94
# 3447            61
# 3621             0
#
# [14 rows x 23 columns]

# %%
# conclusion houses(villa) but in appartments

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']))
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
# sector analysis
plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
# sector analysis
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['price'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %% [markdown]
# ### price

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df[df['area']<10000]['area'],y=df['price'],hue=df['bedRoom'])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df[df['area']<10000]['area'],y=df['price'],hue=df['agePossession'])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
sns.barplot(x=df['bedRoom'],y=df['price'],estimator=np.median, palette='Set2')
# Out:
# C:\Users\ajjur\AppData\Local\Temp\ipykernel_53848\1746565534.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['bedRoom'],y=df['price'],estimator=np.median, palette='Set2')
# <Axes: xlabel='bedRoom', ylabel='price'>

# %%
sns.barplot(x=df['agePossession'],y=df['price'],estimator=np.median, palette='Set2')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\ajjur\AppData\Local\Temp\ipykernel_53848\3987883911.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['agePossession'],y=df['price'],estimator=np.median, palette='Set2')

# %%
sns.barplot(x=df['agePossession'],y=df['area'],estimator=np.median, palette='Set2')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\ajjur\AppData\Local\Temp\ipykernel_53848\3514700120.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['agePossession'],y=df['area'],estimator=np.median, palette='Set2')

# %%
sns.barplot(x=df['furnishing_type'],y=df['price'],estimator=np.median, palette='Set2')
# Out:
# C:\Users\ajjur\AppData\Local\Temp\ipykernel_53848\34992316.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['furnishing_type'],y=df['price'],estimator=np.median, palette='Set2')
# <Axes: xlabel='furnishing_type', ylabel='price'>
